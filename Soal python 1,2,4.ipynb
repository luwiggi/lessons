# %%
import pandas as pd

# %%
dw = pd.read_csv("file csv/python_ dataset_superstore_simple.csv")

# %%
datawiggi
# Out:
#             order_id  order_date customer_id    segment         category  \
# 0     CA-2016-152156  2016-11-08    CG-12520   Consumer        Furniture
# 1     CA-2016-152156  2016-11-08    CG-12520   Consumer        Furniture
# 2     CA-2016-138688  2016-06-12    DV-13045  Corporate  Office Supplies
# 3     US-2015-108966  2015-10-11    SO-20335   Consumer        Furniture
# 4     US-2015-108966  2015-10-11    SO-20335   Consumer  Office Supplies
# ...              ...         ...         ...        ...              ...
# 9983  CA-2014-110422  2014-01-21    TB-21400   Consumer        Furniture
# 9984  CA-2017-121258  2017-02-26    DB-13060   Consumer        Furniture
# 9985  CA-2017-121258  2017-02-26    DB-13060   Consumer       Technology
# 9986  CA-2017-121258  2017-02-26    DB-13060   Consumer  Office Supplies
# 9987  CA-2017-119914  2017-05-04    CC-12220   Consumer  Office Supplies
#
#      sub_category     sales  quantity    profit
# ...

# %%
datawiggi.head()
# Out:
#          order_id  order_date customer_id    segment         category  \
# 0  CA-2016-152156  2016-11-08    CG-12520   Consumer        Furniture
# 1  CA-2016-152156  2016-11-08    CG-12520   Consumer        Furniture
# 2  CA-2016-138688  2016-06-12    DV-13045  Corporate  Office Supplies
# 3  US-2015-108966  2015-10-11    SO-20335   Consumer        Furniture
# 4  US-2015-108966  2015-10-11    SO-20335   Consumer  Office Supplies
#
#   sub_category     sales  quantity    profit
# 0    Bookcases  261.9600         2   41.9136
# 1       Chairs  731.9400         3  219.5820
# 2       Labels   14.6200         2    6.8714
# 3       Tables  957.5775         5 -383.0310
# 4      Storage   22.3680         2    2.5164

# %%
datawiggi.dtypes
# Out:
# order_id         object
# order_date       object
# customer_id      object
# segment          object
# category         object
# sub_category     object
# sales           float64
# quantity          int64
# profit          float64
# dtype: object

# %%
dw = pd.read_csv("file csv/python_ dataset_superstore_simple.csv", parse_dates=["order_date"])
dw.head()
# Out:
#          order_id order_date customer_id    segment         category  \
# 0  CA-2016-152156 2016-11-08    CG-12520   Consumer        Furniture
# 1  CA-2016-152156 2016-11-08    CG-12520   Consumer        Furniture
# 2  CA-2016-138688 2016-06-12    DV-13045  Corporate  Office Supplies
# 3  US-2015-108966 2015-10-11    SO-20335   Consumer        Furniture
# 4  US-2015-108966 2015-10-11    SO-20335   Consumer  Office Supplies
#
#   sub_category     sales  quantity    profit
# 0    Bookcases  261.9600         2   41.9136
# 1       Chairs  731.9400         3  219.5820
# 2       Labels   14.6200         2    6.8714
# 3       Tables  957.5775         5 -383.0310
# 4      Storage   22.3680         2    2.5164

# %%
datawiggi
# Out:
#             order_id  order_date customer_id    segment         category  \
# 0     CA-2016-152156  2016-11-08    CG-12520   Consumer        Furniture
# 1     CA-2016-152156  2016-11-08    CG-12520   Consumer        Furniture
# 2     CA-2016-138688  2016-06-12    DV-13045  Corporate  Office Supplies
# 3     US-2015-108966  2015-10-11    SO-20335   Consumer        Furniture
# 4     US-2015-108966  2015-10-11    SO-20335   Consumer  Office Supplies
# ...              ...         ...         ...        ...              ...
# 9983  CA-2014-110422  2014-01-21    TB-21400   Consumer        Furniture
# 9984  CA-2017-121258  2017-02-26    DB-13060   Consumer        Furniture
# 9985  CA-2017-121258  2017-02-26    DB-13060   Consumer       Technology
# 9986  CA-2017-121258  2017-02-26    DB-13060   Consumer  Office Supplies
# 9987  CA-2017-119914  2017-05-04    CC-12220   Consumer  Office Supplies
#
#      sub_category     sales  quantity    profit
# ...

# %%
dw
# Out:
#             order_id order_date customer_id    segment         category  \
# 0     CA-2016-152156 2016-11-08    CG-12520   Consumer        Furniture
# 1     CA-2016-152156 2016-11-08    CG-12520   Consumer        Furniture
# 2     CA-2016-138688 2016-06-12    DV-13045  Corporate  Office Supplies
# 3     US-2015-108966 2015-10-11    SO-20335   Consumer        Furniture
# 4     US-2015-108966 2015-10-11    SO-20335   Consumer  Office Supplies
# ...              ...        ...         ...        ...              ...
# 9983  CA-2014-110422 2014-01-21    TB-21400   Consumer        Furniture
# 9984  CA-2017-121258 2017-02-26    DB-13060   Consumer        Furniture
# 9985  CA-2017-121258 2017-02-26    DB-13060   Consumer       Technology
# 9986  CA-2017-121258 2017-02-26    DB-13060   Consumer  Office Supplies
# 9987  CA-2017-119914 2017-05-04    CC-12220   Consumer  Office Supplies
#
#      sub_category     sales  quantity    profit
# 0       Bookcases  261.9600         2   41.9136
# ...

# %%
dw.head()
# Out:
#          order_id order_date customer_id    segment         category  \
# 0  CA-2016-152156 2016-11-08    CG-12520   Consumer        Furniture
# 1  CA-2016-152156 2016-11-08    CG-12520   Consumer        Furniture
# 2  CA-2016-138688 2016-06-12    DV-13045  Corporate  Office Supplies
# 3  US-2015-108966 2015-10-11    SO-20335   Consumer        Furniture
# 4  US-2015-108966 2015-10-11    SO-20335   Consumer  Office Supplies
#
#   sub_category     sales  quantity    profit
# 0    Bookcases  261.9600         2   41.9136
# 1       Chairs  731.9400         3  219.5820
# 2       Labels   14.6200         2    6.8714
# 3       Tables  957.5775         5 -383.0310
# 4      Storage   22.3680         2    2.5164

# %%
dw.dtypes
# Out:
# order_id                object
# order_date      datetime64[ns]
# customer_id             object
# segment                 object
# category                object
# sub_category            object
# sales                  float64
# quantity                 int64
# profit                 float64
# dtype: object

# %%
kp = ["CA-2016-152156","CA-2016-152156", "CA-2016-138688","US-2015-108966","US-2015-108966"]
nk = ["Mas Anto", "Juki", "Joseph", "Gandi", "Yayan"]

dw_kurir = pd.DataFrame({
    "kode pesan" : kp,
    "nama kurir" : nk,
})

# %%
dw_kurir
# Out:
#        kode pesan nama kurir
# 0  CA-2016-152156   Mas Anto
# 1  CA-2016-152156       Juki
# 2  CA-2016-138688     Joseph
# 3  US-2015-108966      Gandi
# 4  US-2015-108966      Yayan

# %%
nk = ["Mas Anto", "Juki", None , "Gandi", "Yayan"]

# %%
kp = ["CA-2016-152156","CA-2016-152156", "CA-2016-138688","US-2015-108966","US-2015-108966"]
nk = ["Mas Anto", "Juki", None, "Gandi", "Yayan"]

dw_kurir = pd.DataFrame({
    "kode pesan" : kp,
    "nama kurir" : nk,
})

dw_kurir
# Out:
#        kode pesan nama kurir
# 0  CA-2016-152156   Mas Anto
# 1  CA-2016-152156       Juki
# 2  CA-2016-138688       None
# 3  US-2015-108966      Gandi
# 4  US-2015-108966      Yayan

# %%
dw_kurir.isna()
# Out:
#    kode pesan  nama kurir
# 0       False       False
# 1       False       False
# 2       False        True
# 3       False       False
# 4       False       False

# %%
dw_kurir.isna().any("columns")
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# dtype: bool

# %%
dw_kurir[dw_kurir.isna().any("columns")]
# Out:
#        kode pesan nama kurir
# 2  CA-2016-138688       None

# %%
dw_kurir.to_csv("file csv/data kurir.csv", index=False)

# %%
dataatas = dw.head()

# %%
databawah = dw.tail()

# %%
dataatas
# Out:
#          order_id order_date customer_id    segment         category  \
# 0  CA-2016-152156 2016-11-08    CG-12520   Consumer        Furniture
# 1  CA-2016-152156 2016-11-08    CG-12520   Consumer        Furniture
# 2  CA-2016-138688 2016-06-12    DV-13045  Corporate  Office Supplies
# 3  US-2015-108966 2015-10-11    SO-20335   Consumer        Furniture
# 4  US-2015-108966 2015-10-11    SO-20335   Consumer  Office Supplies
#
#   sub_category     sales  quantity    profit
# 0    Bookcases  261.9600         2   41.9136
# 1       Chairs  731.9400         3  219.5820
# 2       Labels   14.6200         2    6.8714
# 3       Tables  957.5775         5 -383.0310
# 4      Storage   22.3680         2    2.5164

# %%
databawah
# Out:
#             order_id order_date customer_id   segment         category  \
# 9983  CA-2014-110422 2014-01-21    TB-21400  Consumer        Furniture
# 9984  CA-2017-121258 2017-02-26    DB-13060  Consumer        Furniture
# 9985  CA-2017-121258 2017-02-26    DB-13060  Consumer       Technology
# 9986  CA-2017-121258 2017-02-26    DB-13060  Consumer  Office Supplies
# 9987  CA-2017-119914 2017-05-04    CC-12220  Consumer  Office Supplies
#
#      sub_category    sales  quantity   profit
# 9983  Furnishings   25.248         3   4.1028
# 9984  Furnishings   91.960         2  15.6332
# 9985       Phones  258.576         2  19.3932
# 9986        Paper   29.600         4  13.3200
# 9987   Appliances  243.160         2  72.9480

# %%
dataconcat = pd.concat([dataatas, databawah])

# %%
dataconcat
# Out:
#             order_id order_date customer_id    segment         category  \
# 0     CA-2016-152156 2016-11-08    CG-12520   Consumer        Furniture
# 1     CA-2016-152156 2016-11-08    CG-12520   Consumer        Furniture
# 2     CA-2016-138688 2016-06-12    DV-13045  Corporate  Office Supplies
# 3     US-2015-108966 2015-10-11    SO-20335   Consumer        Furniture
# 4     US-2015-108966 2015-10-11    SO-20335   Consumer  Office Supplies
# 9983  CA-2014-110422 2014-01-21    TB-21400   Consumer        Furniture
# 9984  CA-2017-121258 2017-02-26    DB-13060   Consumer        Furniture
# 9985  CA-2017-121258 2017-02-26    DB-13060   Consumer       Technology
# 9986  CA-2017-121258 2017-02-26    DB-13060   Consumer  Office Supplies
# 9987  CA-2017-119914 2017-05-04    CC-12220   Consumer  Office Supplies
#
#      sub_category     sales  quantity    profit
# 0       Bookcases  261.9600         2   41.9136
# 1          Chairs  731.9400         3  219.5820
# ...

# %%
dataconcat.ignore_index=True

# %%
dataconcat
# Out:
#             order_id order_date customer_id    segment         category  \
# 0     CA-2016-152156 2016-11-08    CG-12520   Consumer        Furniture
# 1     CA-2016-152156 2016-11-08    CG-12520   Consumer        Furniture
# 2     CA-2016-138688 2016-06-12    DV-13045  Corporate  Office Supplies
# 3     US-2015-108966 2015-10-11    SO-20335   Consumer        Furniture
# 4     US-2015-108966 2015-10-11    SO-20335   Consumer  Office Supplies
# 9983  CA-2014-110422 2014-01-21    TB-21400   Consumer        Furniture
# 9984  CA-2017-121258 2017-02-26    DB-13060   Consumer        Furniture
# 9985  CA-2017-121258 2017-02-26    DB-13060   Consumer       Technology
# 9986  CA-2017-121258 2017-02-26    DB-13060   Consumer  Office Supplies
# 9987  CA-2017-119914 2017-05-04    CC-12220   Consumer  Office Supplies
#
#      sub_category     sales  quantity    profit
# 0       Bookcases  261.9600         2   41.9136
# 1          Chairs  731.9400         3  219.5820
# ...

# %%
dataconcat = pd.concat([dataatas, databawah], ignore_index=True)

# %%
dataconcat
# Out:
#          order_id order_date customer_id    segment         category  \
# 0  CA-2016-152156 2016-11-08    CG-12520   Consumer        Furniture
# 1  CA-2016-152156 2016-11-08    CG-12520   Consumer        Furniture
# 2  CA-2016-138688 2016-06-12    DV-13045  Corporate  Office Supplies
# 3  US-2015-108966 2015-10-11    SO-20335   Consumer        Furniture
# 4  US-2015-108966 2015-10-11    SO-20335   Consumer  Office Supplies
# 5  CA-2014-110422 2014-01-21    TB-21400   Consumer        Furniture
# 6  CA-2017-121258 2017-02-26    DB-13060   Consumer        Furniture
# 7  CA-2017-121258 2017-02-26    DB-13060   Consumer       Technology
# 8  CA-2017-121258 2017-02-26    DB-13060   Consumer  Office Supplies
# 9  CA-2017-119914 2017-05-04    CC-12220   Consumer  Office Supplies
#
#   sub_category     sales  quantity    profit
# 0    Bookcases  261.9600         2   41.9136
# 1       Chairs  731.9400         3  219.5820
# 2       Labels   14.6200         2    6.8714
# ...

# %%
dataconcat = pd.concat([dataatas, databawah], index=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-79-3ab11ec7edf2> in <module>
# ----> 1 dataconcat = pd.concat([dataatas, databawah], index=True)
#
# TypeError: concat() got an unexpected keyword argument 'index'

# %%
dataconcat = pd.concat([dataatas, databawah], index=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-80-52e9442a630a> in <module>
# ----> 1 dataconcat = pd.concat([dataatas, databawah], index=False)
#
# TypeError: concat() got an unexpected keyword argument 'index'

# %%
dataconcat = pd.concat([dataatas, databawah], ignore_index=True)

# %%
dataconcat
# Out:
#          order_id order_date customer_id    segment         category  \
# 0  CA-2016-152156 2016-11-08    CG-12520   Consumer        Furniture
# 1  CA-2016-152156 2016-11-08    CG-12520   Consumer        Furniture
# 2  CA-2016-138688 2016-06-12    DV-13045  Corporate  Office Supplies
# 3  US-2015-108966 2015-10-11    SO-20335   Consumer        Furniture
# 4  US-2015-108966 2015-10-11    SO-20335   Consumer  Office Supplies
# 5  CA-2014-110422 2014-01-21    TB-21400   Consumer        Furniture
# 6  CA-2017-121258 2017-02-26    DB-13060   Consumer        Furniture
# 7  CA-2017-121258 2017-02-26    DB-13060   Consumer       Technology
# 8  CA-2017-121258 2017-02-26    DB-13060   Consumer  Office Supplies
# 9  CA-2017-119914 2017-05-04    CC-12220   Consumer  Office Supplies
#
#   sub_category     sales  quantity    profit
# 0    Bookcases  261.9600         2   41.9136
# 1       Chairs  731.9400         3  219.5820
# 2       Labels   14.6200         2    6.8714
# ...

# %%
dataconcat.sort_values("order_date", ascending=False)
# Out:
#          order_id order_date customer_id    segment         category  \
# 9  CA-2017-119914 2017-05-04    CC-12220   Consumer  Office Supplies
# 6  CA-2017-121258 2017-02-26    DB-13060   Consumer        Furniture
# 7  CA-2017-121258 2017-02-26    DB-13060   Consumer       Technology
# 8  CA-2017-121258 2017-02-26    DB-13060   Consumer  Office Supplies
# 0  CA-2016-152156 2016-11-08    CG-12520   Consumer        Furniture
# 1  CA-2016-152156 2016-11-08    CG-12520   Consumer        Furniture
# 2  CA-2016-138688 2016-06-12    DV-13045  Corporate  Office Supplies
# 3  US-2015-108966 2015-10-11    SO-20335   Consumer        Furniture
# 4  US-2015-108966 2015-10-11    SO-20335   Consumer  Office Supplies
# 5  CA-2014-110422 2014-01-21    TB-21400   Consumer        Furniture
#
#   sub_category     sales  quantity    profit
# 9   Appliances  243.1600         2   72.9480
# 6  Furnishings   91.9600         2   15.6332
# 7       Phones  258.5760         2   19.3932
# ...

# %%
dataconcat = dataconcat.sort_values("order_date", ascending=False)

# %%
dataconcat
# Out:
#          order_id order_date customer_id    segment         category  \
# 9  CA-2017-119914 2017-05-04    CC-12220   Consumer  Office Supplies
# 6  CA-2017-121258 2017-02-26    DB-13060   Consumer        Furniture
# 7  CA-2017-121258 2017-02-26    DB-13060   Consumer       Technology
# 8  CA-2017-121258 2017-02-26    DB-13060   Consumer  Office Supplies
# 0  CA-2016-152156 2016-11-08    CG-12520   Consumer        Furniture
# 1  CA-2016-152156 2016-11-08    CG-12520   Consumer        Furniture
# 2  CA-2016-138688 2016-06-12    DV-13045  Corporate  Office Supplies
# 3  US-2015-108966 2015-10-11    SO-20335   Consumer        Furniture
# 4  US-2015-108966 2015-10-11    SO-20335   Consumer  Office Supplies
# 5  CA-2014-110422 2014-01-21    TB-21400   Consumer        Furniture
#
#   sub_category     sales  quantity    profit
# 9   Appliances  243.1600         2   72.9480
# 6  Furnishings   91.9600         2   15.6332
# 7       Phones  258.5760         2   19.3932
# ...

# %%
datawiggi
# Out:
#             order_id  order_date customer_id    segment         category  \
# 0     CA-2016-152156  2016-11-08    CG-12520   Consumer        Furniture
# 1     CA-2016-152156  2016-11-08    CG-12520   Consumer        Furniture
# 2     CA-2016-138688  2016-06-12    DV-13045  Corporate  Office Supplies
# 3     US-2015-108966  2015-10-11    SO-20335   Consumer        Furniture
# 4     US-2015-108966  2015-10-11    SO-20335   Consumer  Office Supplies
# ...              ...         ...         ...        ...              ...
# 9983  CA-2014-110422  2014-01-21    TB-21400   Consumer        Furniture
# 9984  CA-2017-121258  2017-02-26    DB-13060   Consumer        Furniture
# 9985  CA-2017-121258  2017-02-26    DB-13060   Consumer       Technology
# 9986  CA-2017-121258  2017-02-26    DB-13060   Consumer  Office Supplies
# 9987  CA-2017-119914  2017-05-04    CC-12220   Consumer  Office Supplies
#
#      sub_category     sales  quantity    profit
# ...

# %%
datacustomer = datawiggi.groupby(["customer_id"]).agg({
    "sales" : "sum",
}).sort_values("sales", ascending=False)

# %%
datacustomer
# Out:
#                  sales
# customer_id
# AB-10105     14473.571
# KL-16645     14175.229
# SC-20095     14142.334
# SE-20110     12209.438
# CC-12370     12129.072
# ...                ...
# RS-19870        22.328
# MG-18205        16.739
# CJ-11875        16.520
# LD-16855         5.304
# TS-21085         4.833
#
# [793 rows x 1 columns]

# %%
data_OS = datawiggi.groupby(["category", "sub_category"]).agg({
        "sales" : "sum",
})

# %%
data_OS
# Out:
#                                     sales
# category        sub_category
# Furniture       Bookcases     114879.9963
#                 Chairs        328449.1030
#                 Furnishings    91705.1640
#                 Tables        206965.5320
# Office Supplies Appliances    107532.1610
#                 Art            27118.7920
#                 Binders       203412.7330
#                 Envelopes      16476.4020
#                 Fasteners       3024.2800
#                 Labels         12486.3120
#                 Paper          78479.2060
#                 Storage       223843.6080
#                 Supplies       46673.5380
# Technology      Accessories   167380.3180
#                 Copiers        96328.1820
#                 Machines      162100.1660
#                 Phones        330007.0540

# %%
dataprofit = datawiggi.groupby("profit").agg({
        "quantity" : "sum",
})

# %%
dataprofit
# Out:
#             quantity
# profit
# -3839.9904         4
# -3701.8928         8
# -3399.9800         5
# -2929.4845         5
# -2639.9912         2
# ...              ...
#  2591.9568         9
#  2799.9840         5
#  3177.4750         5
#  4630.4755         5
#  4946.3700        13
#
# [7281 rows x 1 columns]

# %%
datawiggi
# Out:
#             order_id  order_date customer_id    segment         category  \
# 0     CA-2016-152156  2016-11-08    CG-12520   Consumer        Furniture
# 1     CA-2016-152156  2016-11-08    CG-12520   Consumer        Furniture
# 2     CA-2016-138688  2016-06-12    DV-13045  Corporate  Office Supplies
# 3     US-2015-108966  2015-10-11    SO-20335   Consumer        Furniture
# 4     US-2015-108966  2015-10-11    SO-20335   Consumer  Office Supplies
# ...              ...         ...         ...        ...              ...
# 9983  CA-2014-110422  2014-01-21    TB-21400   Consumer        Furniture
# 9984  CA-2017-121258  2017-02-26    DB-13060   Consumer        Furniture
# 9985  CA-2017-121258  2017-02-26    DB-13060   Consumer       Technology
# 9986  CA-2017-121258  2017-02-26    DB-13060   Consumer  Office Supplies
# 9987  CA-2017-119914  2017-05-04    CC-12220   Consumer  Office Supplies
#
#      sub_category     sales  quantity    profit
# ...

# %%
datawiggi[datawiggi.profit==(-)]
# Out:
#   File "<ipython-input-315-ac622c70b309>", line 1
#     datawiggi[datawiggi.profit==(-)]
#                                   ^
# SyntaxError: invalid syntax

# %%
JE= datawiggi[datawiggi.customer_id=='JE-16165']

# %%
KH = datawiggi[datawiggi.customer_id=='KH-16510']

# %%
AD = datawiggi[datawiggi.customer_id=='AD-10180']

# %%
datacustomer= pd.concat([JE,KH,AD])

# %%
datacustomer
# Out:
#             order_id  order_date customer_id      segment         category  \
# 147   CA-2016-114489  2016-12-05    JE-16165    Corporate       Technology
# 148   CA-2016-114489  2016-12-05    JE-16165    Corporate       Technology
# 149   CA-2016-114489  2016-12-05    JE-16165    Corporate        Furniture
# 150   CA-2016-114489  2016-12-05    JE-16165    Corporate  Office Supplies
# 3186  US-2017-146416  2017-10-20    JE-16165    Corporate  Office Supplies
# 3187  US-2017-146416  2017-10-20    JE-16165    Corporate  Office Supplies
# 6904  US-2017-135503  2017-12-10    JE-16165    Corporate        Furniture
# 405   CA-2017-117457  2017-12-08    KH-16510     Consumer       Technology
# 406   CA-2017-117457  2017-12-08    KH-16510     Consumer       Technology
# 407   CA-2017-117457  2017-12-08    KH-16510     Consumer  Office Supplies
# 408   CA-2017-117457  2017-12-08    KH-16510     Consumer        Furniture
# ...

# %%
datacustomer.groupby('customer_id').agg({
    'quantity' : 'sum'
})
# Out:
#              quantity
# customer_id
# AD-10180           40
# JE-16165           34
# KH-16510           91

# %%
datawiggi = datawiggi, (parse_dates=["order_date"])
# Out:
#   File "<ipython-input-337-dd1352ec2b3b>", line 1
#     datawiggi = datawiggi, (parse_dates=["order_date"])
#                                        ^
# SyntaxError: invalid syntax

# %%
dw
# Out:
#             order_id order_date customer_id    segment         category  \
# 0     CA-2016-152156 2016-11-08    CG-12520   Consumer        Furniture
# 1     CA-2016-152156 2016-11-08    CG-12520   Consumer        Furniture
# 2     CA-2016-138688 2016-06-12    DV-13045  Corporate  Office Supplies
# 3     US-2015-108966 2015-10-11    SO-20335   Consumer        Furniture
# 4     US-2015-108966 2015-10-11    SO-20335   Consumer  Office Supplies
# ...              ...        ...         ...        ...              ...
# 9983  CA-2014-110422 2014-01-21    TB-21400   Consumer        Furniture
# 9984  CA-2017-121258 2017-02-26    DB-13060   Consumer        Furniture
# 9985  CA-2017-121258 2017-02-26    DB-13060   Consumer       Technology
# 9986  CA-2017-121258 2017-02-26    DB-13060   Consumer  Office Supplies
# 9987  CA-2017-119914 2017-05-04    CC-12220   Consumer  Office Supplies
#
#      sub_category     sales  quantity    profit
# 0       Bookcases  261.9600         2   41.9136
# ...
